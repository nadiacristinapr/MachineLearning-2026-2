# %% [markdown]
# #Análise Descritiva RJ

# %%
#Carregando os pacotes

# %%
import pandas as pd  # processamento de bancos de dados
import numpy as np  # processamento numérico
import matplotlib.pyplot as plt  # geração de gráficos
import seaborn as sns  # geração de gráficos alternativos

# Configuração de gráficos no notebook
# %matplotlib inline
plt.rcParams["figure.figsize"] = [10, 5]
plt.style.use("fivethirtyeight")
# %config InlineBackend.figure_format = 'retina'

# Configurações de fonte e matemática
from matplotlib import rc
rc('font', **{'family': 'sans-serif', 'sans-serif': ['DejaVu Sans'], 'size': 10})
rc('mathtext', **{'default': 'regular'})

# %%
df = pd.read_csv("dadosRJ_tube_2015_2025.csv",sep=",")

# %%
df.shape
# Out:
# (25630, 35)

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'dt_inic_tr',
#        'bacilosc_2', 'bacilosc_4', 'tratsup_at', 'dt_encerra', 'pop_liber',
#        'pop_rua', 'pop_imig', 'benef_gov', 'agravdroga', 'agravtabac',
#        'ano_base', 'cura', 'pop', 'front', 'tempo_diag_trat_14', 'dt_cul',
#        'dt_bac2', 'dt_bac4', 'eleg_eta2', 'eleg_eta3', 'ano_inc_trat',
#        'ano_encerra', 'escola_faixa', 'contato_5_15', 'faixa_etaria'],
#       dtype='object')

# %%
df['pop'].describe()
# Out:
# count    2.562700e+04
# mean     4.212033e+06
# std      2.683237e+06
# min      1.020700e+04
# 25%      8.081610e+05
# 50%      6.211223e+06
# 75%      6.211223e+06
# max      6.211223e+06
# Name: pop, dtype: float64

# %%
import pandas as pd

# Criação da variável categórica com pd.cut
df['pop_grupo'] = pd.cut(
    df['pop'],
    bins=[-float('inf'),300000, 1000000, float('inf')],
    labels=['< 300000', '300000 a 1000000', '>1000000']
)

# %%
df['pop_grupo'].value_counts(dropna=False)
# Out:
# pop_grupo
# >1000000            16458
# 300000 a 1000000     7473
# < 300000             1696
# NaN                     3
# Name: count, dtype: int64

# %%
df['ano_encerra'].value_counts(dropna=False)
# Out:
# ano_encerra
# 2023    4472
# 2022    3803
# 2021    3047
# 2019    2974
# 2020    2892
# 2024    2832
# 2018    2539
# 2016    1211
# 2017    1052
# 2015     788
# 2025      20
# Name: count, dtype: int64

# %%
df['ano_enc_grupo'] = pd.cut(
    df['ano_encerra'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_enc_grupo'].value_counts(dropna=False)
# Out:
# ano_enc_grupo
# 2015-2022    18306
# 2023-2024     7324
# Name: count, dtype: int64

# %%
df['ano_inc_trat'].value_counts(dropna=False)
# Out:
# ano_inc_trat
# 2023    4953
# 2022    4180
# 2021    3319
# 2019    3049
# 2018    2859
# 2020    2816
# 2017    2376
# 2015    2008
# 2024      55
# 2016      14
# 2025       1
# Name: count, dtype: int64

# %%
df['ano_inctr_grupo'] = pd.cut(
    df['ano_inc_trat'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_inctr_grupo'].value_counts(dropna=False)
# Out:
# ano_inctr_grupo
# 2015-2022    20621
# 2023-2024     5009
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'dt_inic_tr',
#        'bacilosc_2', 'bacilosc_4', 'tratsup_at', 'dt_encerra', 'pop_liber',
#        'pop_rua', 'pop_imig', 'benef_gov', 'agravdroga', 'agravtabac',
#        'ano_base', 'cura', 'pop', 'front', 'tempo_diag_trat_14', 'dt_cul',
#        'dt_bac2', 'dt_bac4', 'eleg_eta2', 'eleg_eta3', 'ano_inc_trat',
#        'ano_encerra', 'escola_faixa', 'contato_5_15', 'faixa_etaria',
#        'pop_grupo', 'ano_enc_grupo', 'ano_inctr_grupo'],
#       dtype='object')

# %% [markdown]
# ###Atualizando categorias das variaveis

# %%
df['cs_raca'].value_counts(dropna=False)
# Out:
# cs_raca
# 4.0    11698
# 1.0     6514
# 2.0     5766
# 9.0     1299
# 3.0      216
# NaN       98
# 5.0       39
# Name: count, dtype: int64

# %%
import numpy as np

df['cs_raca'] = df['cs_raca'].replace(9, np.nan)

# %%
df['raiox_tora'].value_counts(dropna=False)
# Out:
# raiox_tora
# 1.0    21723
# 4.0     3204
# 2.0      604
# NaN       78
# 0.0       21
# Name: count, dtype: int64

# %%
import numpy as np

df['raiox_tora'] = df['raiox_tora'].replace(0, np.nan)

# %%
df['bacilosc_2'].value_counts(dropna=False)
# Out:
# bacilosc_2
# 3.0    12124
# 2.0     6740
# NaN     4587
# 1.0     1490
# 0.0      689
# Name: count, dtype: int64

# %%
import numpy as np

df['bacilosc_2'] = df['bacilosc_2'].replace(0, np.nan)

# %%
df['bacilosc_4'].value_counts(dropna=False)
# Out:
# bacilosc_4
# 3.0    13799
# NaN     6057
# 2.0     4665
# 0.0      865
# 1.0      244
# Name: count, dtype: int64

# %%
import numpy as np

df['bacilosc_4'] = df['bacilosc_4'].replace(0, np.nan)

# %%
df['tratsup_at'].value_counts(dropna=False)
# Out:
# tratsup_at
# 1.0    13248
# 2.0     9271
# NaN     2408
# 0.0      548
# 9.0      155
# Name: count, dtype: int64

# %%
import numpy as np

df['tratsup_at'] = df['tratsup_at'].replace(0, np.nan)

# %%
import numpy as np

df['tratsup_at'] = df['tratsup_at'].replace(9, np.nan)

# %% [markdown]
# ###Etapa1

# %%
df.shape
# Out:
# (25630, 38)

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
#Lista de variáveis com o desfecho
lista_variaveis = [ 'cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'bacilosc_e',
                    'front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20798                    81.15
# 0                    4832                    18.85
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    17635                    68.81
# 0.0                     7993                    31.19
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         12637                    49.31
# 2.0                          7317                    28.55
# 3.0                          3394                    13.24
# 0.0                          2260                     8.82
# NaN                            22                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = [ 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'bacilosc_e',
                    'front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df[var].astype('object').where(df[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                 1006                    12.59
# 1     0.0     1                 6987                    87.41
# 2     1.0     0                 3826                    21.70
# 3     1.0     1                13809                    78.30
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  383                    16.95
# 1          0.0     1                 1877                    83.05
# 2          1.0     0                 2901                    22.96
# 3          1.0     1                 9736                    77.04
# 4          2.0     0                 1128                    15.42
# 5          2.0     1                 6189                    84.58
# ...

# %% [markdown]
# ###Etapas 2 e 3

# %%
df2 = df.loc[df['eleg_eta2'] == 1].copy()
df3 = df.loc[df['eleg_eta3'] == 1].copy()

# %% [markdown]
# ###Etapa 2

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
df2.shape
# Out:
# (24537, 38)

# %%
#Lista de variáveis com o desfecho
lista_variaveis = [ 'cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df2[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df2[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20537                     83.7
# 0                    4000                     16.3
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    16822                    68.56
# 0.0                     7713                    31.43
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         12139                    49.47
# 2.0                          7012                    28.58
# 3.0                          3184                    12.98
# 0.0                          2181                     8.89
# NaN                            21                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = [ 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df2[var].astype('object').where(df2[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df2[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                  815                    10.57
# 1     0.0     1                 6898                    89.43
# 2     1.0     0                 3185                    18.93
# 3     1.0     1                13637                    81.07
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  325                    14.90
# 1          0.0     1                 1856                    85.10
# 2          1.0     0                 2534                    20.87
# 3          1.0     1                 9605                    79.13
# 4          2.0     0                  907                    12.93
# 5          2.0     1                 6105                    87.07
# ...

# %% [markdown]
# ###Etapa 3

# %%
df3.shape
# Out:
# (23121, 38)

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
#Lista de variáveis com o desfecho
lista_variaveis = ['cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'bacilosc_4','tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df3[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df3[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20395                    88.21
# 0                    2726                    11.79
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    15715                    67.97
# 0.0                     7404                    32.02
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         11288                    48.82
# 2.0                          6670                    28.85
# 3.0                          3084                    13.34
# 0.0                          2059                     8.91
# NaN                            20                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = ['cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'bacilosc_4','tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df3[var].astype('object').where(df3[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df3[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                  550                     7.43
# 1     0.0     1                 6854                    92.57
# 2     1.0     0                 2176                    13.85
# 3     1.0     1                13539                    86.15
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  215                    10.44
# 1          0.0     1                 1844                    89.56
# 2          1.0     0                 1763                    15.62
# 3          1.0     1                 9525                    84.38
# 4          2.0     0                  607                     9.10
# 5          2.0     1                 6063                    90.90
# ...

# %% [markdown]
# #Análise Descritiva RJ

# %%
#Carregando os pacotes

# %%
import pandas as pd  # processamento de bancos de dados
import numpy as np  # processamento numérico
import matplotlib.pyplot as plt  # geração de gráficos
import seaborn as sns  # geração de gráficos alternativos

# Configuração de gráficos no notebook
# %matplotlib inline
plt.rcParams["figure.figsize"] = [10, 5]
plt.style.use("fivethirtyeight")
# %config InlineBackend.figure_format = 'retina'

# Configurações de fonte e matemática
from matplotlib import rc
rc('font', **{'family': 'sans-serif', 'sans-serif': ['DejaVu Sans'], 'size': 10})
rc('mathtext', **{'default': 'regular'})

# %% [markdown]
# ###Etapa1

# %%
df = pd.read_csv("dfrj1.csv",sep=",")

# %%
df.shape
# Out:
# (25630, 26)

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'pop_liber', 'pop_rua',
#        'pop_imig', 'benef_gov', 'agravdroga', 'agravtabac', 'ano_base', 'cura',
#        'pop', 'front', 'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat',
#        'ano_encerra', 'escola_faixa', 'contato_5_15', 'faixa_etaria'],
#       dtype='object')

# %%
df['pop'].describe()
# Out:
# count    2.562700e+04
# mean     4.212033e+06
# std      2.683237e+06
# min      1.020700e+04
# 25%      8.081610e+05
# 50%      6.211223e+06
# 75%      6.211223e+06
# max      6.211223e+06
# Name: pop, dtype: float64

# %%
import pandas as pd

# Criação da variável categórica com pd.cut
df['pop_grupo'] = pd.cut(
    df['pop'],
    bins=[-float('inf'),300000, 1000000, float('inf')],
    labels=['< 300000', '300000 a 1000000', '>1000000']
)

# %%
df['pop_grupo'].value_counts(dropna=False)
# Out:
# pop_grupo
# >1000000            16458
# 300000 a 1000000     7473
# < 300000             1696
# NaN                     3
# Name: count, dtype: int64

# %%
df['ano_encerra'].value_counts(dropna=False)
# Out:
# ano_encerra
# 2023    4472
# 2022    3803
# 2021    3047
# 2019    2974
# 2020    2892
# 2024    2832
# 2018    2539
# 2016    1211
# 2017    1052
# 2015     788
# 2025      20
# Name: count, dtype: int64

# %%
df['ano_enc_grupo'] = pd.cut(
    df['ano_encerra'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_enc_grupo'].value_counts(dropna=False)
# Out:
# ano_enc_grupo
# 2015-2022    18306
# 2023-2024     7324
# Name: count, dtype: int64

# %%
df['ano_inc_trat'].value_counts(dropna=False)
# Out:
# ano_inc_trat
# 2023    4953
# 2022    4180
# 2021    3319
# 2019    3049
# 2018    2859
# 2020    2816
# 2017    2376
# 2015    2008
# 2024      55
# 2016      14
# 2025       1
# Name: count, dtype: int64

# %%
df['ano_inctr_grupo'] = pd.cut(
    df['ano_inc_trat'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_inctr_grupo'].value_counts(dropna=False)
# Out:
# ano_inctr_grupo
# 2015-2022    20621
# 2023-2024     5009
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'pop_liber', 'pop_rua',
#        'pop_imig', 'benef_gov', 'agravdroga', 'agravtabac', 'ano_base', 'cura',
#        'pop', 'front', 'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat',
#        'ano_encerra', 'escola_faixa', 'contato_5_15', 'faixa_etaria',
#        'pop_grupo', 'ano_enc_grupo', 'ano_inctr_grupo'],
#       dtype='object')

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
#Lista de variáveis com o desfecho
lista_variaveis = [ 'cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'bacilosc_e',
                    'front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20798                    81.15
# 0                    4832                    18.85
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    17635                    68.81
# 0.0                     7993                    31.19
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         12637                    49.31
# 2.0                          7317                    28.55
# 3.0                          3394                    13.24
# 0.0                          2260                     8.82
# NaN                            22                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = [ 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'bacilosc_e',
                    'front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df[var].astype('object').where(df[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                 1006                    12.59
# 1     0.0     1                 6987                    87.41
# 2     1.0     0                 3826                    21.70
# 3     1.0     1                13809                    78.30
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  383                    16.95
# 1          0.0     1                 1877                    83.05
# 2          1.0     0                 2901                    22.96
# 3          1.0     1                 9736                    77.04
# 4          2.0     0                 1128                    15.42
# 5          2.0     1                 6189                    84.58
# ...

# %% [markdown]
# ###Etapa2

# %%
df = pd.read_csv("dfrj2.csv",sep=",")

# %%
df.shape
# Out:
# (24537, 29)

# %%
df.shape
# Out:
# (24537, 29)

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'bacilosc_2',
#        'tratsup_at', 'pop_liber', 'pop_rua', 'pop_imig', 'benef_gov',
#        'agravdroga', 'agravtabac', 'ano_base', 'cura', 'pop', 'front',
#        'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat', 'ano_encerra',
#        'escola_faixa', 'contato_5_15', 'faixa_etaria'],
#       dtype='object')

# %%
df['pop'].describe()
# Out:
# count    2.453400e+04
# mean     4.226834e+06
# std      2.677561e+06
# min      1.182800e+04
# 25%      8.081610e+05
# 50%      6.211223e+06
# 75%      6.211223e+06
# max      6.211223e+06
# Name: pop, dtype: float64

# %%
import pandas as pd

# Criação da variável categórica com pd.cut
df['pop_grupo'] = pd.cut(
    df['pop'],
    bins=[-float('inf'),300000, 1000000, float('inf')],
    labels=['< 300000', '300000 a 1000000', '>1000000']
)

# %%
df['pop_grupo'].value_counts(dropna=False)
# Out:
# pop_grupo
# >1000000            15816
# 300000 a 1000000     7124
# < 300000             1594
# NaN                     3
# Name: count, dtype: int64

# %%
df['ano_encerra'].value_counts(dropna=False)
# Out:
# ano_encerra
# 2023    4267
# 2022    3599
# 2021    2909
# 2019    2873
# 2024    2803
# 2020    2771
# 2018    2432
# 2016    1201
# 2017     972
# 2015     691
# 2025      19
# Name: count, dtype: int64

# %%
df['ano_enc_grupo'] = pd.cut(
    df['ano_encerra'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_enc_grupo'].value_counts(dropna=False)
# Out:
# ano_enc_grupo
# 2015-2022    17448
# 2023-2024     7089
# Name: count, dtype: int64

# %%
df['ano_inc_trat'].value_counts(dropna=False)
# Out:
# ano_inc_trat
# 2023    4740
# 2022    3983
# 2021    3179
# 2019    2949
# 2018    2755
# 2020    2686
# 2017    2284
# 2015    1903
# 2024      46
# 2016      12
# Name: count, dtype: int64

# %%
df['ano_inctr_grupo'] = pd.cut(
    df['ano_inc_trat'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_inctr_grupo'].value_counts(dropna=False)
# Out:
# ano_inctr_grupo
# 2015-2022    19751
# 2023-2024     4786
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'bacilosc_2',
#        'tratsup_at', 'pop_liber', 'pop_rua', 'pop_imig', 'benef_gov',
#        'agravdroga', 'agravtabac', 'ano_base', 'cura', 'pop', 'front',
#        'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat', 'ano_encerra',
#        'escola_faixa', 'contato_5_15', 'faixa_etaria', 'pop_grupo',
#        'ano_enc_grupo', 'ano_inctr_grupo'],
#       dtype='object')

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
#Lista de variáveis com o desfecho
lista_variaveis = [ 'cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo'
                  ]

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20537                     83.7
# 0                    4000                     16.3
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    16822                    68.56
# 0.0                     7713                    31.43
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         12139                    49.47
# 2.0                          7012                    28.58
# 3.0                          3184                    12.98
# 0.0                          2181                     8.89
# NaN                            21                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = [ 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df[var].astype('object').where(df[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                  815                    10.57
# 1     0.0     1                 6898                    89.43
# 2     1.0     0                 3185                    18.93
# 3     1.0     1                13637                    81.07
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  325                    14.90
# 1          0.0     1                 1856                    85.10
# 2          1.0     0                 2534                    20.87
# 3          1.0     1                 9605                    79.13
# 4          2.0     0                  907                    12.93
# 5          2.0     1                 6105                    87.07
# ...

# %% [markdown]
# ###Etapa3

# %%
df = pd.read_csv("dfrj3.csv",sep=",")

# %%
df.shape
# Out:
# (23121, 30)

# %%
df.shape
# Out:
# (23121, 30)

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'bacilosc_2',
#        'bacilosc_4', 'tratsup_at', 'pop_liber', 'pop_rua', 'pop_imig',
#        'benef_gov', 'agravdroga', 'agravtabac', 'ano_base', 'cura', 'pop',
#        'front', 'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat', 'ano_encerra',
#        'escola_faixa', 'contato_5_15', 'faixa_etaria'],
#       dtype='object')

# %%
df['pop'].describe()
# Out:
# count    2.311800e+04
# mean     4.275912e+06
# std      2.662878e+06
# min      1.182800e+04
# 25%      8.081610e+05
# 50%      6.211223e+06
# 75%      6.211223e+06
# max      6.211223e+06
# Name: pop, dtype: float64

# %%
import pandas as pd

# Criação da variável categórica com pd.cut
df['pop_grupo'] = pd.cut(
    df['pop'],
    bins=[-float('inf'),300000, 1000000, float('inf')],
    labels=['< 300000', '300000 a 1000000', '>1000000']
)

# %%
df['pop_grupo'].value_counts(dropna=False)
# Out:
# pop_grupo
# >1000000            15109
# 300000 a 1000000     6510
# < 300000             1499
# NaN                     3
# Name: count, dtype: int64

# %%
df['ano_encerra'].value_counts(dropna=False)
# Out:
# ano_encerra
# 2023    3998
# 2022    3380
# 2021    2730
# 2024    2715
# 2019    2703
# 2020    2627
# 2018    2281
# 2016    1163
# 2017     885
# 2015     620
# 2025      19
# Name: count, dtype: int64

# %%
df['ano_enc_grupo'] = pd.cut(
    df['ano_encerra'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_enc_grupo'].value_counts(dropna=False)
# Out:
# ano_enc_grupo
# 2015-2022    16389
# 2023-2024     6732
# Name: count, dtype: int64

# %%
df['ano_inc_trat'].value_counts(dropna=False)
# Out:
# ano_inc_trat
# 2023    4454
# 2022    3752
# 2021    2988
# 2019    2782
# 2018    2587
# 2020    2545
# 2017    2167
# 2015    1795
# 2024      40
# 2016      11
# Name: count, dtype: int64

# %%
df['ano_inctr_grupo'] = pd.cut(
    df['ano_inc_trat'],
    bins=[2014, 2022, float('inf')],
    labels=['2015-2022', '2023-2024']
)

# %%
df['ano_inctr_grupo'].value_counts(dropna=False)
# Out:
# ano_inctr_grupo
# 2015-2022    18627
# 2023-2024     4494
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['nu_ano', 'cs_sexo', 'cs_raca', 'sg_uf', 'raiox_tora', 'agravalcoo',
#        'agravdiabe', 'agravdoenc', 'bacilosc_e', 'cultura_es', 'bacilosc_2',
#        'bacilosc_4', 'tratsup_at', 'pop_liber', 'pop_rua', 'pop_imig',
#        'benef_gov', 'agravdroga', 'agravtabac', 'ano_base', 'cura', 'pop',
#        'front', 'tempo_diag_trat_14', 'dt_cul', 'ano_inc_trat', 'ano_encerra',
#        'escola_faixa', 'contato_5_15', 'faixa_etaria', 'pop_grupo',
#        'ano_enc_grupo', 'ano_inctr_grupo'],
#       dtype='object')

# %% [markdown]
# ##Proporção dos preditores e desfecho

# %%
#Lista de variáveis com o desfecho
lista_variaveis = ['cura', 'cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'bacilosc_4','tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# %%
for coluna in lista_variaveis:
    print(f"\n==== Variável: {coluna} ====")

    # Frequência absoluta
    freq_abs = df[coluna].value_counts(dropna=False)

    # Frequência relativa (em %)
    freq_rel = df[coluna].value_counts(normalize=True, dropna=False) * 100

    # Juntar em um único DataFrame para visualização
    tabela = pd.DataFrame({
        'Frequência Absoluta': freq_abs,
        'Frequência Relativa (%)': freq_rel.round(2)
    })

    print(tabela)
# Out:
# ==== Variável: cura ====
#       Frequência Absoluta  Frequência Relativa (%)
# cura
# 1                   20395                    88.21
# 0                    2726                    11.79
#
# ==== Variável: cs_sexo ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_sexo
# 1.0                    15715                    67.97
# 0.0                     7404                    32.02
# NaN                        2                     0.01
#
# ==== Variável: faixa_etaria ====
#               Frequência Absoluta  Frequência Relativa (%)
# faixa_etaria
# 1.0                         11288                    48.82
# 2.0                          6670                    28.85
# 3.0                          3084                    13.34
# 0.0                          2059                     8.91
# NaN                            20                     0.09
#
# ==== Variável: cs_raca ====
#          Frequência Absoluta  Frequência Relativa (%)
# cs_raca
# ...

# %%
# Listas
lista_variavel_desfecho = ['cura']

lista_preditores = ['cs_sexo', 'faixa_etaria','cs_raca', 'escola_faixa', 'contato_5_15',
                   'pop_rua','pop_liber','pop_imig','benef_gov', 'agravtabac','agravalcoo','agravdroga',
                    'agravdiabe', 'agravdoenc', 'tempo_diag_trat_14','raiox_tora', 'cultura_es','bacilosc_e',
                    'bacilosc_2', 'bacilosc_4','tratsup_at','front', 'ano_inctr_grupo','ano_enc_grupo','pop_grupo']

# Dicionário para salvar os resultados
resultados = {}

desfecho = lista_variavel_desfecho[0]

for var in lista_preditores:

    # Versão temporária sem NA (convertendo para object)
    temp_var = df[var].astype('object').where(df[var].notna(), 'NA')

    # Contagem
    tabela = (
        pd.DataFrame({var: temp_var, desfecho: df[desfecho]})
        .groupby([var, desfecho], dropna=False)
        .size()
        .rename("Frequência Absoluta")
        .reset_index()
    )

    # Frequência relativa
    tabela["Frequência Relativa (%)"] = (
        tabela["Frequência Absoluta"]
        / tabela.groupby(var)["Frequência Absoluta"].transform("sum")
        * 100
    ).round(2)

    resultados[var] = tabela

# Exibir
for var, tabela in resultados.items():
    print(f"\n==== Variável: {var} ====")
    print(tabela)
# Out:
# ==== Variável: cs_sexo ====
#   cs_sexo  cura  Frequência Absoluta  Frequência Relativa (%)
# 0     0.0     0                  550                     7.43
# 1     0.0     1                 6854                    92.57
# 2     1.0     0                 2176                    13.85
# 3     1.0     1                13539                    86.15
# 4      NA     1                    2                   100.00
#
# ==== Variável: faixa_etaria ====
#   faixa_etaria  cura  Frequência Absoluta  Frequência Relativa (%)
# 0          0.0     0                  215                    10.44
# 1          0.0     1                 1844                    89.56
# 2          1.0     0                 1763                    15.62
# 3          1.0     1                 9525                    84.38
# 4          2.0     0                  607                     9.10
# 5          2.0     1                 6063                    90.90
# ...
